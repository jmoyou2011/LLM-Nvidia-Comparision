# %% [markdown]
# # Nvidia Foundational Large Language Models Async
# The Nvidia foundational Large Language Models (LLMs) are hosted on the catalog.ngc.nvidia.com webpage. Nvidia provides these models through either streaming or non-streaming process APIs for anyone to interact with many models. Nvidia provides an API key to developers to interact with these LLMs without a cost such as the OPENAI API and the rate-limiting of OPENAI. This allows new developers to experiment with LLMs with limited knowledge of the underlying architecture to obtain responses from prompts supplied.
#
# In this notebook, we will look at 11 models that are labeled text-to-text models on their catalog. Since all the APIs for the models are the same except the last path item which is the uuid for the model. These APIs will be called using the Python requests module. Other request modules such as async with aiohttp, and httpx.
#
# NOTE
# There was experimentation with aiohttp with asyncio with the API calls. There are few issues discovered:
#
# 1. Some models will return a 200 status code instead of the expected 202. This required a rewrite to account
#    for this problem.
#
# 2. This problem is variable as it is not consistent with a particular model. If you want to async
#    call the API for each model for a single prompt, one to a few of the models will return with an empty
#    response. The amount of models that return an empty response will vary with each call.

# %%
import requests as req
import os, sys
import asyncio
import nest_asyncio
import aiohttp
import time
import yaml
import json
import pandas as pd
from asyncio_throttle import Throttler

# %% [markdown]
# ### Initialization
# In the cell below we will initialize our global variables that will be used by the LLM functions.
#
# #### NOTE:
# At the time of making this notebook, Mamba-chat had been released to the Nvidia catalog page on 02/12/2024.
# It was not included in the set of testing due to the payload differing in structure from the other which will
# require a rework to include.

# %%
nest_asyncio.apply()
model_dict = {
    "mixtral8x7binstruct": "8f4118ba-60a8-4e6b-8574-e38a4067a4a3",
    "mistral7binstruct": "35ec3354-2681-4d0e-a8dd-80325dcf7c63",
    "nv-llama2-70b-rlhf": "7b3e3361-4266-41c8-b312-f5e33c81fc92",
    "nv-llama2-70b-steerlm": "d6fe6881-973a-4279-a0f8-e1d486c9618d",
    "codellama13b": "f6a96af4-8bf9-4294-96d6-d71aa787612e",
    "codellama70b": "2ae529dc-f728-4a46-9b8d-2697213666d8",
    "codellama34b": "df2bee43-fb69-42b9-9ee5-f4eabbeaf3a8",
    "llama213b": "e0bb7fb9-5333-4a27-8534-c6288f921d3f",
    "llama270b": "0e349b44-440a-44e1-93e9-abe8dcb27158",
    "yi-34b": "347fa3f3-d675-432c-b844-669ef8ee53df",
    "nemotron-3-8b-chat-steerlm": "1423ff2f-d1c7-4061-82a7-9e8c67afd43a",
}

invoke_url = "https://api.nvcf.nvidia.com/v2/nvcf/pexec/functions/"
fetch_url_format = "https://api.nvcf.nvidia.com/v2/nvcf/pexec/status/"

model_urls = {}
for k, v in model_dict.items():
    model_urls[k] = invoke_url + v

lst_urls = list(model_urls.values())
model_key = list(model_urls.keys())

# %%
os.environ["NGCKEY"] = "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"
my_api = os.environ.get('NGCKEY')

# %% [markdown]
# ### LLM Functions
# Two main LLM functions interact with the Nvidia LLMs. All the models
# are interfacing with Nvidia Triton. Some of the models indicate what GPU/GPUS are
# used for the interfacing while some indicate others. Comparisons may not be "apple-to-apple"
# due to not all models interfacing with the same hardware.
#
# One function named "llm_invoke" works by invoking a model name and prompt to return the model
# response. This works with a helper function that formats the response to be displayed in the gradio
# interface.
#
# The second function is similar to the first model saves the output in the list of dictionaries with a
# similar gradio formatting function supplementing it.

# %%
async def llm_invoke_model(model_name: str, prompt: str) -> str: 
    """
    This function will call from any model within the dictionary from Nvidia
    AI foundational models and run the model. This is strictly focused on
    the text-to-text models found on the link below:

    https://catalog.ngc.nvidia.com/orgs/nvidia/teams/ai-foundation/models

    Models that require context are not included in the dictionary.

    Inputs
    model_name (str): Name of the model
    prompt (str): Prompt to be passed to the model

    Outputs
    msg (str): Text generated from the model given the prompt
    resp_time (str): Time taken to generate the response
    out_Tokens (str): Number of tokens returned from the LLM.

    """
    model_name = model_name.lower().replace(" ", "")

    if model_name not in model_dict.keys():
        print("Model name not found in dictionary, using default model")
        print("Default model is NV-Llama2-70B-RLHF")
        model_name = "nv-llama2-70b-rlhf"

    url = model_urls[model_name]
    

    headers = {
    "Authorization": "Bearer " + str(my_api),
    "Accept": "application/json",
      }

    payload = {
      "messages": [
        {
          "content": str(prompt),
          "role": "user"
        }
      ],
      "temperature": 0.2,
      "top_p": 0.7,
      "max_tokens": 1024,
      "seed": 42,
      "stream": False
      }
    url = model_urls[model_name]
    
    start_time = time.time()
    async with aiohttp.ClientSession(headers = headers) as session:
        async with session.post(url, json = payload) as response:
            print(response.status)
            if response.status == 200:
                end_time = time.time()
                body_resp = json.loads(await response.text())
                elapsed = round((end_time - start_time), 3)
                msg = body_resp.get('choices')[0].get('message').get('content')
                out_tkns = body_resp.get('usage').get('completion_tokens')
            elif response.status == 202:
                request_id = response.headers.get("NVCF-REQID")
                fetch_url = fetch_url_format + request_id
                async with session.get(fetch_url, headers = headers) as resp:
                    print("{}".format(resp.status))
                    end_time = time.time()
                    body_resp = await resp.json(content_type=None)
                    msg = body_resp.get('choices')[0].get('message').get('content')
                    elapsed = round((end_time - start_time), 3)
                    out_tkns = body_resp.get('usage').get('completion_tokens')

    return msg, elapsed, out_tkns


async def return_llm_resp(model_name: str, prompt: str) -> None:
    rsp_msg , rsp_time, rsp_tkns = await llm_invoke_model(model_name, prompt)
    output = f"{rsp_msg}\n\nResponse Time:{rsp_time} seconds\n\nOutput tokens:{rsp_tkns}"
    print(output)

# %% [markdown]
# #### Testing Async call to the API

# %%
await return_llm_resp("nv-llama2-70b-rlhf", "I am visiting paris, what should I see? Limit to five best spots.")
# Out:
# 202
# 200
# Sure! Here are the top 5 places to visit in Paris:
#
# 1. Eiffel Tower - One of the most iconic landmarks in the world, the Eiffel Tower offers stunning views of the city.
# 2. Louvre Museum - Home to some of the world's most famous artworks, including the Mona Lisa, the Louvre is a must-visit for art lovers.
# 3. Notre Dame Cathedral - A stunning example of French Gothic architecture, Notre Dame is a beautiful and historic site to visit.
# 4. Arc de Triomphe - This iconic monument, located at the end of the Champs-Elysees, offers great views of the city and is a symbol of French history.
# 5. Montmartre - This charming neighborhood is home to the Sacre-Coeur Basilica, as well as many artists, cafes, and boutiques. It offers great views of the city and is a great place to wander and soak up the Parisian atmosphere.
# These are just a few of the many amazing places to visit in Paris. Other notable sites include the Palace of Versailles, the Luxembourg Gardens, and the Pompidou Center. No matter where you go, you're sure to be charmed by the beauty and history of this amazing city.
#
# Response Time:9.931 seconds
#
# Output tokens:292

# %%
df = pd.read_csv('./Data/questions.csv', sep=",")
lst_questions = df['questions'].values
df.head()
# Out:
#                                            questions
# 0     What are the top tourist attractions in Paris?
# 1  How does the Eiffel Tower contribute to the ci...
# 2      What is the history behind the Louvre Museum?
# 3  How does the Notre-Dame Cathedral represent Go...
# 4  What are some popular neighborhoods to explore...

# %%
async def my_routine_all(session ,model: str,prompt: str) -> dict:
    
    headers = {
    "Authorization": "Bearer " + str(my_api),
    "Accept": "application/json",
      }

    payload = {
      "messages": [
        {
          "content": str(prompt),
          "role": "user"
        }
      ],
      "temperature": 0.2,
      "top_p": 0.7,
      "max_tokens": 1024,
      "seed": 42,
      "stream": False
      }
    
    tmp_dict = {}
    start_time = time.time()
    async with session.post(model_urls[model], json = payload, headers = headers) as response:
        # print("{}\n{}\n{}".format(model, response.status, await response.text()))
        if response.status == 200:
            end_time = time.time()
            body_resp = json.loads(await response.text())
            elapsed = round((end_time - start_time), 3)
            msg = body_resp.get('choices')[0].get('message').get('content')
            out_tkns = body_resp.get('usage').get('completion_tokens')
            tmp_dict = {
                    "Response": msg,
                    "Response_time": elapsed,
                    "Output_tokens": out_tkns,
                    "Model": model}
        elif response.status == 202:
            request_id = response.headers.get("NVCF-REQID")
            fetch_url = fetch_url_format + request_id
            async with session.get(fetch_url, headers = headers) as resp:
                resp.raise_for_status()
                end_time = time.time()
                body_resp = await resp.json(content_type=None)
                # body_resp = json.loads(await response.text())
                elapsed = round((end_time - start_time), 3)
                try:
                    msg = body_resp.get('choices')[0].get('message').get('content')
                    out_tkns = body_resp.get('usage').get('completion_tokens')
                except:
                    msg, out_tkns = "Error Retrieving", 0
                tmp_dict = {
                    "Response": msg,
                    "Response_time": elapsed,
                    "Output_tokens": out_tkns,
                    "Model": model}

    return tmp_dict

                            
                    
async def fetch_all(session, prompt):
    tasks = [asyncio.create_task(my_routine_all(session, model, prompt)) for model in model_key]
    results = await asyncio.gather(*tasks)
    return results
    
        
async def test_main(prompt):
    async with aiohttp.ClientSession() as session:
        documents = await fetch_all(session, prompt)
        for document in documents:
            print(f"{document}\n\n")

# %%
if __name__ == "__main__":
    test_prompt = "Describe the catacombs in Paris."
    asyncio.run(test_main(test_prompt))
# Out:
# {'Response': "The catacombs in Paris, France, are a series of underground ossuaries that hold the remains of millions of people. They were created in the late 18th century due to the city's overcrowded cemeteries. The catacombs stretch over 200 miles beneath the streets of Paris, but only a small portion is open to the public.\n\nThe sections that are open to visitors contain carefully arranged bones and skulls, creating a unique and somewhat eerie display. The walls are etched with quotes and poems, adding to the mysterious atmosphere. Visitors can learn about the history of the catacombs and the people whose remains are interred there.\n\nIt's important to note that the catacombs are not a typical tourist attraction. They are dark, damp, and can be claustrophobic. However, for those interested in history, architecture, or the macabre, they offer a one-of-a-kind experience. \n\nVisitors should remember to show respect for the deceased and their families while visiting the catacombs. It's also crucial to stay safe by following all rules and guidelines, and to avoid any dangerous or disrespectful behavior.", 'Response_time': 4.014, 'Output_tokens': 260, 'Model': 'mixtral8x7binstruct'}
#
#
# {'Response': 'The Catacombs of Paris, located in the south of the city, are an intriguing and historic site that offers a unique exploration into the city\'s past. This vast underground ossuary holds the remains of millions of Parisians, dating back to the late 18th century.\n\nThe Catacombs were created due to the overcrowding of Parisian cemeteries. In 1785, the city\'s authorities decided to transfer the bones from the overfilled cemeteries to the old quarries located beneath the city. The process continued until 1860, resulting in the impressive and macabre display that can be seen today.\n\nThe Catacombs stretch for approximately 130 hectares, but only a small portion is open to the public. The visitable area consists of a series of long, narrow corridors and vast chambers, adorned with intricately arranged bones. The most famous chamber is the "Murs des Fossoyeurs" or the "Wall of the Dead," where the bones are arranged in intricate patterns and designs.\n\nThe temperature in the Catacombs remains a constant 14 degrees Celsius (57 degrees Fahrenheit), making it a refreshing escape from the heat of the city during the summer months. The humidity level is also high, which helps to preserve the bones.\n\nVisiting the Catacombs is an unforgettable experience, offering a glimpse into the history and culture of Paris. It is essential to remember that the site is a place of respect and contemplation, and visitors are asked to treat it as such. The Catacombs are open every day except Mondays and certain holidays. It is recommended to book tickets in advance to avoid long lines.', 'Response_time': 4.912, 'Output_tokens': 378, 'Model': 'mistral7binstruct'}
#
#
# {'Response': "The Catacombs of Paris are a network of underground tunnels and galleries located beneath the streets of Paris, France. They were originally built as a series of quarries to provide building materials for the city, but were later converted into a massive ossuary to hold the remains of millions of Parisians. The Catacombs hold the remains of approximately 6 million people, many of whom were moved there from overcrowded cemeteries in the 18th and 19th centuries.\n\nVisitors to the Catacombs can take a guided tour through the underground tunnels, which are lined with stacks of bones and skulls arranged in intricate patterns. The Catacombs also feature a number of memorials and monuments, including a statue of the Virgin Mary and a memorial to the victims of the French Revolution.\n\nThe Catacombs are a popular tourist attraction in Paris, and are known for their eerie and haunting atmosphere. However, they are also an important historical site, providing insight into the city's past and the lives of its inhabitants.", 'Response_time': 8.32, 'Output_tokens': 246, 'Model': 'nv-llama2-70b-rlhf'}
#
#
# {'Response': 'The Catacombs of Paris are a network of underground tunnels and galleries located in the 14th arrondissement of Paris, France. They are a popular tourist attraction and a unique historical site that offers a glimpse into the city\'s past.\n\nThe Catacombs were originally limestone quarries that were used to build many of the city\'s famous landmarks, including the Louvre and Notre Dame Cathedral. In the late 18th century, the quarries were converted into an ossuary to hold the remains of millions of Parisians who were moved there from overcrowded cemeteries.\n\nToday, visitors can take a guided tour of the Catacombs and see the remains of more than six million people, arranged in neat rows and stacks along the walls of the tunnels. The tunnels are dimly lit and the atmosphere is eerie, with the bones and skulls of the dead serving as a reminder of the city\'s past.\n\nIn addition to the bones, the Catacombs also feature a number of sculptures and carvings, including a recreation of the "Barrel of Passion," a sculpture that was originally located in the Saint-Eustache Church. The Catacombs also feature a number of informational plaques and displays that provide information about the history of the site and the people who were buried there.\n\nOverall, the Catacombs of Paris are a fascinating and unique attraction that offers a glimpse into the city\'s past. They are a must-see for anyone interested in history, art, or the macabre.', 'Response_time': 8.244, 'Output_tokens': 368, 'Model': 'nv-llama2-70b-steerlm'}
#
#
# {'Response': 'Error Retrieving', 'Response_time': 10.908, 'Output_tokens': 0, 'Model': 'codellama13b'}
#
#
# {'Response': "🗺️ The Catacombs of Paris are a vast underground network of tunnels and chambers that contain the remains of millions of people. They are located beneath the city's historic cemeteries and are a fascinating and eerie place to explore. Here's a brief description of the catacombs:\n\n**Location:** The catacombs are located beneath the city's historic cemeteries, including the Cimetière des Innocents, Cimetière Saint-Jean, and Cimetière Saint-Vincent.\n\n**History:** The catacombs were created in the 18th century as a solution to the overcrowding of Paris's cemeteries. The remains of the deceased were exhumed and transferred to the catacombs, which were designed to hold the remains of up to 6 million people.\n\n**Layout:** The catacombs are a vast network of tunnels and chambers that are divided into three main sections:\n\n1. The Grand Ossuary: This is the main entrance to the catacombs, where visitors can see the remains of the deceased arranged in rows.\n2. The Ossuary of the Bones: This section contains the remains of the deceased, which are arranged in rows and stacked in layers.\n3. The Ossuary of the Skulls: This section contains the skulls of the deceased, which are arranged in rows and stacked in layers.\n\n**Visiting:** The catacombs are open to the public and can be visited as part of a guided tour. Tours are offered in French, English, and other languages. Visitors can explore the catacombs and learn about the history and significance of the remains.\n\n**Notable features:** The catacombs are known for their eerie atmosphere and the vast number of human remains. Visitors can see the remains of the deceased arranged in rows and stacked in layers, creating a surreal and haunting atmosphere.\n\n**Conclusion:** The Catacombs of Paris are a fascinating and eerie place to explore. They offer a unique glimpse into the history of Paris and the lives of the people who lived there. Visitors can learn about the history of the catacombs and the remains of the deceased, creating a memorable and unforgettable experience.", 'Response_time': 10.908, 'Output_tokens': 532, 'Model': 'codellama70b'}
#
#
# {'Response': 'The catacombs of Paris are a network of underground tunnels and chambers that stretch for over 170 miles (270 km) beneath the city. They were built in the 18th century as a solution to the problem of overcrowding in the city\'s cemeteries, and were used as a place to inter the dead until the mid-19th century.\n\nThe catacombs are made up of a series of tunnels and chambers, some of which are decorated with skulls and bones, while others are more plain. The tunnels are often narrow and winding, and the air is damp and musty. In some places, the walls are covered in moss and other vegetation, giving the impression of a natural cave system.\n\nThe catacombs are divided into several sections, each of which is dedicated to a different period of Parisian history. Some of the most notable sections include the Catacombs of the Calvary, which contain the remains of over 6 million people, and the Catacombs of the Saint-Boniface, which are decorated with elaborate frescoes and sculptures.\n\nVisitors to the catacombs can take guided tours, which provide a fascinating glimpse into the history and culture of Paris. The tours typically include information about the history of the catacombs, as well as the lives and deaths of the people who were buried there. Some tours also include the opportunity to see the catacombs\' most famous attraction, the "Bone Lady" (La Dame aux Ossements), a skeleton dressed in a wedding gown and holding a bouquet of flowers.\n\nOverall, the catacombs of Paris are a unique and fascinating attraction that offer a glimpse into the city\'s rich history and culture.', 'Response_time': 4.949, 'Output_tokens': 417, 'Model': 'codellama34b'}
#
#
# {'Response': 'Hello! I\'d be happy to help you with your question about the catacombs in Paris.\n\nThe Catacombs of Paris, also known as the Catacombes de Paris, are a network of underground tunnels and chambers that stretch for over 150 miles beneath the city. They were created in the 18th century as a solution to the city\'s overcrowded cemeteries, and were used to store the remains of millions of Parisians.\n\nThe catacombs are located beneath the streets of Paris, and are accessible through a series of entrances and exits. The tunnels are narrow and winding, and are often quite dark and damp. Visitors can explore the catacombs on guided tours, which provide a unique glimpse into the history and culture of Paris.\n\nOne of the most famous sections of the catacombs is the "Empire of Death," which features a series of elaborate stone sculptures and inscriptions that reflect the attitudes of the time towards death and the afterlife. Other sections of the catacombs include the "King\'s Ditch," which was used as a mass grave during the French Revolution, and the "Crypt of the Resistance," which honors the members of the French Resistance who fought against the Nazis during World War II.\n\nOverall, the catacombs of Paris are a fascinating and unique attraction that offer a glimpse into the history and culture of the city. However, please note that the catacombs can be quite dark and damp, and may not be suitable for all visitors. It\'s always a good idea to check the conditions and accessibility of the catacombs before planning a visit.', 'Response_time': 8.243, 'Output_tokens': 386, 'Model': 'llama213b'}
#
#
# {'Response': 'The Catacombs of Paris, also known as the Paris Catacombs, are a network of underground tunnels and chambers located beneath the city of Paris, France. The catacombs were created in the 18th century as a solution to the city\'s overcrowded cemeteries, and they contain the remains of millions of Parisians.\n\nThe Catacombs of Paris are a labyrinthine network of tunnels that stretch for over 250 kilometers (155 miles) beneath the city. They are located approximately 20 meters (66 feet) below street level, and they are accessible through a series of entrance points located throughout the city.\n\nThe tunnels are lined with bones and skulls, arranged in a macabre but fascinating display. The remains are those of Parisians who were buried in the city\'s cemeteries during the 18th and 19th centuries, but were later moved to the catacombs to make way for new burials. The bones are arranged in a hierarchical manner, with the remains of the wealthy and famous placed in the most prominent positions.\n\nVisitors to the Catacombs of Paris can take a guided tour of a section of the tunnels, which includes a visit to the famous "Bone Chapel" or "Chapelle de la Bonne-Dame." This chapel is decorated with intricate carvings and contains a large number of skulls and bones, arranged in a ornate and eerie display.\n\nThe Catacombs of Paris are a popular tourist destination, attracting millions of visitors each year. However, they are also a place of historical and cultural significance, providing a unique glimpse into the history of Paris and the lives of its inhabitants.\n\nIt\'s worth noting that the Catacombs of Paris are not suitable for everyone, as they can be quite claustrophobic and may not be suitable for people with a weak constitution. Additionally, the tunnels can be damp and chilly, so it\'s recommended to dress appropriately and bring a jacket or sweater.', 'Response_time': 7.22, 'Output_tokens': 481, 'Model': 'llama270b'}
#
#
# {'Response': "The Paris Catacombs are a network of underground ossuaries located in the 14th arrondissement of Paris, France. They hold the remains of an estimated 6 million people and were created in the 18th century as a solution to the overflowing cemeteries in the city. The Catacombs are made up of a series of tunnels and chambers that were originally quarries used to extract limestone for the construction of Paris.\n\nAs the city grew, so did the number of burials, and by the late 18th century, the cemeteries were becoming a public health hazard due to the lack of space and the poor sanitary conditions. The Catacombs were thus converted into a massive burial site, with the bones being exhumed from the cemeteries and arranged in the underground chambers.\n\nThe Catacombs are known for their eerie atmosphere and the macabre display of human remains. The walls are lined with skulls and bones arranged in various patterns and designs, and the air is heavy with the scent of death. The Catacombs have become a popular tourist attraction, offering visitors a glimpse into the history and culture of Paris.\n\nIt's important to note that the Catacombs are not a place of recent burials; they are a historical site that serves as a memorial to the many people buried there. Access to the Catacombs is limited and requires a guided tour, as the tunnels can be dangerous due to their maze-like structure and the risk of flooding.", 'Response_time': 6.4, 'Output_tokens': 331, 'Model': 'yi-34b'}
#
#
# {'Response': 'The Catacombs of Paris are a network of underground tunnels and chambers located beneath the city of Paris, France. They were originally built as a system of quarries in the 17th century to supply stone to the city. Today, they are a popular tourist attraction and are used for various purposes, including as a burial ground for the dead.\n\nThe Catacombs are made up of a series of interconnected tunnels and chambers, some of which are very large and can accommodate up to 200 people at a time. The tunnels are narrow and winding, and are often filled with bones and other human remains. The walls are covered in inscriptions and graffiti, and the air is thick with dust and humidity.\n\nThe Catacombs are divided into several sections, each with its own unique atmosphere and history. The most famous section is the "Ossuary," which is filled with bones from the dead. The "Catacombs of the Soldiers" are filled with the remains of soldiers who died in the French Revolution, while the "Catacombs of the Dead" are filled with the remains of those who died in the Great Plague of 1720.\n\nVisitors to the Catacombs are not allowed to touch the bones, but they can explore the tunnels and chambers and learn about the history of the dead. The Catacombs are a fascinating and eerie place, and are sure to leave a lasting impression on anyone who visits.', 'Response_time': 6.81, 'Output_tokens': 297, 'Model': 'nemotron-3-8b-chat-steerlm'}
